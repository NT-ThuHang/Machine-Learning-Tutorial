# %% [markdown]
# Muốn làm ML mà không biết download dataset sao làm, nên mình nghĩ đây là bài rất quan trọng vì mình từng rất lận đận để có thể download 1 dataset, và bỏ cuộc mấy lần vì vụ này. Nói vậy chứ không phải giớ mình pro mà mình đang lận đận theo một cách khác. huhu

# %% [markdown]
# #Đầu tiên là với !wget

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data
# Out:
# --2021-06-07 17:57:08--  https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3974305 (3.8M) [application/x-httpd-php]
# Saving to: ‘adult.data’
#
# adult.data          100%[===================>]   3.79M  8.85MB/s    in 0.4s
#
# 2021-06-07 17:57:09 (8.85 MB/s) - ‘adult.data’ saved [3974305/3974305]

# %% [markdown]
# Với !wget nó sẽ tải về và lưu cái tệp cuối link lại, nên không đúng tên của tệp nó cũng lưu luôn mà lưu cái gì mình cũng ko rõ nữa nên cứ chắc là có tên tệp mình cần thì hẳn dùng

# %% [markdown]
# #Thứ hai là với !gdown ( cái này lưu ý nhớ !pip install gdown nha)

# %%
# !pip install gdown

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# cú pháp !gdown https://drive.google.com/uc?id=<cái này điền cái id vô>

# %%
# !gdown https://drive.google.com/uc?id=1PZ_6Zsy1Vb0s0JmjEmVd8FS99zoMCiN1
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1PZ_6Zsy1Vb0s0JmjEmVd8FS99zoMCiN1
# To: /content/facenet_keras.h5
# 92.4MB [00:00, 113MB/s]

# %% [markdown]
# ###Nhấp vô phần tệp bên tay trái là thấy tải được facenet_keras.h5 liền thấy hem

# %% [markdown]
# #Với Kaggle
# Òi oi để em :v

# %% [markdown]
# Đầu tiên phải có account Kaggle. Cái này em làm đươc mà nên chắc mọi người cũng làm được

# %% [markdown]
# Sau cái đầu tiên là cái sau đầu tiên mình click vô cái avt á => Chọn Account => Nhấp vô Create New API như này
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Bước 3:

# %%
# !pip install -q kaggle

# %% [markdown]
# Bước 4:![image.png](data:image/png;base64,...)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3105cbec-cb9e-455d-8702-6eba4266ae6c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3105cbec-cb9e-455d-8702-6eba4266ae6c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (1).json
# {'kaggle.json': b'{"username":"ntthuhang","key":"2df78b8e83d8257d208b8e6b18323250"}'}

# %% [markdown]
# Bước 5: tạo thư mực

# %%
# !mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %% [markdown]
# Bước 6: Copy cái kaggle.json nãy á qua cái folder mới tạo

# %%
# !cp kaggle.json ~/.kaggle

# %% [markdown]
# Bước 7:

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                         title                                              size  lastUpdated          downloadCount
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              229KB  2021-06-01 11:18:46           6948
# crowww/a-large-scale-fish-dataset                           A Large Scale Fish Dataset                          3GB  2021-04-28 17:03:01           4160
# imsparsh/musicnet-dataset                                   MusicNet Dataset                                   22GB  2021-02-18 14:12:19           1385
# dhruvildave/wikibooks-dataset                               Wikibooks Dataset                                   1GB  2021-02-18 10:08:27           2153
# ...

# %% [markdown]
# #Lần đầu tiên là chuyện ấy

# %% [markdown]
# Bước 1: Giả bộ vô cái dataset này nha https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition/data

# %% [markdown]
# Bước 2: Chọn cái nút late submission rồi accept mới tải được nhen
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Bước 3: copy cái này nè
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Bước 4: Rồi paste vô chạy hơi mình cài API rồi mà nhưng nhớ thêm ! nhớ, cài gì cũng cho nó vô

# %%
! kaggle competitions download -c dogs-vs-cats-redux-kernels-edition
# Out:
# ...
# 100% 542M/544M [00:05<00:00, 119MB/s]
# 100% 544M/544M [00:05<00:00, 99.1MB/s]
# ...
#  98% 265M/271M [00:02<00:00, 102MB/s]
# 100% 271M/271M [00:02<00:00, 114MB/s]
# ...
#   0% 0.00/111k [00:00<?, ?B/s]
# 100% 111k/111k [00:00<00:00, 122MB/s]

# %% [markdown]
# #Lưu ý

# %% [markdown]
# Cái này chỉ lưu trên ram mà colab cấp cho bạn trong 24h sau đó nó mất tiêu, bạn phải chạy lại , nếu dataset nhỏ thì hoi nếu lớn quá thì đỡ tốn công bạn nên lưu vào drive của mình bằng cách

# %% [markdown]
# Click vô cái link cái chọn cái tài khoản bạn muốn lưu => copy cái code và dán vô ô
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Code nó hình dạng như này:
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Rồi mấy lệnh kia chạy dưới là nó auto lưu vô drive cho bạn nha, nhưng lưu ý phải dùng !cd để chỉ nó chỗ lưu nha, không là nó lưu bậy bạ rồi đi tìm mệt xỉu á, mà thiệt ra làm gì ngu ngok cũng sẽ để lại hậu quả ngu lường á :v
